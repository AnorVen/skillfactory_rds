# %%
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind
pd.set_option('display.max_rows', 400) # показывать больше строк
pd.set_option('display.max_columns', 30) # показывать больше колонок
stud = pd.read_csv('./stud_math.csv')

# %% [markdown]
# load data

# %%
stud.info()
stud.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   school               395 non-null    object
#  1   sex                  395 non-null    object
#  2   age                  395 non-null    int64
#  3   address              378 non-null    object
#  4   famsize              368 non-null    object
#  5   Pstatus              350 non-null    object
#  6   Medu                 392 non-null    float64
#  7   Fedu                 371 non-null    float64
#  8   Mjob                 376 non-null    object
#  9   Fjob                 359 non-null    object
#  10  reason               378 non-null    object
#  11  guardian             364 non-null    object
#  12  traveltime           367 non-null    float64
#  13  studytime            388 non-null    float64
#  14  failures             373 non-null    float64
#  15  schoolsup            386 non-null    object
#  16  famsup               356 non-null    object
#  17  paid                 355 non-null    object
#  18  activities           381 non-null    object
#  19  nursery              379 non-null    object
#  20  studytime, granular  388 non-null    float64
#  21  higher               375 non-null    object
#  22  internet             361 non-null    object
#  23  romantic             364 non-null    object
#  24  famrel               368 non-null    float64
#  25  freetime             384 non-null    float64
#  26  goout                387 non-null    float64
#  27  health               380 non-null    float64
#  28  absences             383 non-null    float64
#  29  score                389 non-null    float64
# dtypes: float64(12), int64(1), object(17)
# memory usage: 92.7+ KB
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     NaN       A   4.0   4.0  at_home  teacher
# 1     GP   F   17       U     GT3     NaN   1.0   1.0  at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0  at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0   health      NaN
# 4     GP   F   16       U     GT3       T   3.0   3.0    other    other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother         2.0        2.0       0.0       yes     no   no
# 1  course   father         1.0        2.0       0.0        no    yes   no
# 2   other   mother         1.0        2.0       3.0       yes     no  NaN
# 3    home   mother         1.0        3.0       0.0        no    yes  yes
# 4    home   father         1.0        2.0       0.0        no    yes  yes
#
#   activities nursery  studytime, granular higher internet romantic  famrel  \
# 0         no     yes                 -6.0    yes      NaN       no     4.0
# 1         no      no                 -6.0    yes      yes       no     5.0
# 2         no     yes                 -6.0    yes      yes      NaN     4.0
# 3        yes     yes                 -9.0    yes      yes      yes     3.0
# 4         no     yes                 -6.0    yes       no       no     4.0
#
#    freetime  goout  health  absences  score
# 0       3.0    4.0     3.0       6.0   30.0
# 1       3.0    3.0     3.0       4.0   30.0
# 2       3.0    2.0     3.0      10.0   50.0
# 3       2.0    2.0     5.0       2.0   75.0
# 4       3.0    2.0     5.0       4.0   50.0

# %% [markdown]
# Резюме:
# -загрузились 30 столбцов, а в описании 29 - ??? интересно почему ???
# -всего 395 записей
#
# 2.Первичный анализ данных в столбцах
# Из описания датасета и первичного осмотра видно, что:
# -Числовых рядов - 3 (три): age, absences, score
# -Бинарных (два значения) - 12: sex, address, famsize, Pstatus, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic
# -Оценочные (несколько значений) - 13: Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, famrel, freetime, goout, health
# -Остальные (в том числе Номинальные) (их пока мы не можем отнести к какой-нибудь группе) - 2: school, studytime_granular
# проверяем - всего 30 столбцов
# столбец 'studytime, granular' - отсутствует в описании

# %%
print(f'There are {stud.isnull().any().sum()} columns in dataset with missing values.')
# Out:
# There are 27 columns in dataset with missing values.

# %%
stud.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'score'],
#       dtype='object')

# %%
stud.columns = ['school', 'sex', 'age', 'address', 'fam_size', 'p_status', 'm_edu', 'f_edu',
       'm_job', 'f_job', 'reason', 'guardian', 'travel_time', 'study_time',
       'fail_res', 'school_sup', 'fam_sup', 'paid', 'activities', 'nursery',
       'studytime_granular', 'higher', 'internet', 'romantic', 'fam_rel',
       'free_time', 'go_out', 'health', 'absences', 'score']

# %% [markdown]
# num var, bin vars

# %%
num_vars = stud[['age', 'absences','score']]

# %%
num_vars.age.isna().sum()
# Out:
# 0

# %%
num_vars.age.hist()
num_vars.age.describe()
# Out:
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
num_vars.absences.isna().sum()
# Out:
# 12

# %%
num_vars.absences.hist()
num_vars.absences.describe()
# Out:
# count    383.000000
# mean       7.279373
# std       23.465197
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max      385.000000
# Name: absences, dtype: float64

# %%
num_vars.absences.unique()
num_vars.absences.value_counts()
# Out:
# 0.0      111
# 2.0       60
# 4.0       53
# 6.0       31
# 8.0       21
# 10.0      17
# 12.0      12
# 14.0      12
# 3.0        8
# 16.0       7
# 7.0        6
# 5.0        5
# 18.0       5
# 20.0       4
# 22.0       3
# 9.0        3
# 1.0        3
# 15.0       2
# 13.0       2
# 11.0       2
# 25.0       1
# 54.0       1
# 385.0      1
# 26.0       1
# 56.0       1
# 24.0       1
# 212.0      1
# 21.0       1
# 75.0       1
# 30.0       1
# 19.0       1
# 38.0       1
# 40.0       1
# 23.0       1
# 17.0       1
# 28.0       1
# Name: absences, dtype: int64

# %%
median = num_vars.absences.median()
IQR = num_vars.absences.quantile(0.75) - num_vars.absences.quantile(0.25)
perc25 = num_vars.absences.quantile(0.25)
perc75 = num_vars.absences.quantile(0.75)

# %%
#perc75 + 1.5*IQR  = 40
perc75_new = 40
num_vars.absences = num_vars.absences.apply(lambda x: 40 if x >=40 else x)
temp_absences_mean = num_vars.absences.mean()
num_vars.absences = num_vars.absences.apply(lambda x: temp_absences_mean if pd.isna(x) else x)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75)
      , "IQR: {}, ".format(IQR),"Границы выбросов: [{f}, принят за 40].".format(f=perc25 - 1.5*IQR))
num_vars.absences.loc[num_vars.absences.between(perc25 - 1.5*IQR, perc75_new)].hist(bins = 10, range = (0, 40), 
                                                                                             label = 'IQR')
plt.legend();
# Out:
# 25-й перцентиль: 0.0, 75-й перцентиль: 8.0, IQR: 8.0,  Границы выбросов: [-12.0, принят за 40].
# /Users/g.efremov/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
temp_absences_mean = num_vars.absences.mean()
num_vars.absences = num_vars.absences.apply(lambda x: 40 if x >=40 else temp_absences_mean if pd.isna(x) else x)

# %%
stud.nursery.unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
temp = stud.nursery.mode()
temp
# Out:
# 0    yes
# dtype: object

# %%
stud.nursery = stud.nursery.apply(lambda x: temp[0] if pd.isna(x) else x)

# %%
stud.address.isna().unique()
# Out:
# array([False,  True])

# %%
stud.m_edu.hist()
stud.m_edu.describe()
# Out:
# count    392.000000
# mean       2.750000
# std        1.098127
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: m_edu, dtype: float64

# %%
stud.f_edu.hist()
stud.f_edu.describe()
# Out:
# count    371.000000
# mean       2.614555
# std        2.228732
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max       40.000000
# Name: f_edu, dtype: float64

# %%
# 40 - выброс **
stud.loc[stud.f_edu > 4, 'f_edu'] = 4

# %%
stud.f_edu.hist()
stud.f_edu.describe()
# Out:
# count    371.000000
# mean       2.517520
# std        1.088808
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: f_edu, dtype: float64

# %%
mafa_edu = stud[['m_edu', 'f_edu']].dropna()
mafa_edu.corr()
# Out:
#           m_edu     f_edu
# m_edu  1.000000  0.625516
# f_edu  0.625516  1.000000

# %%
for i in stud.index:
    if stud['f_edu'][i] not in range(0, 4):
        stud['f_edu'][i] = stud['m_edu'][i]
    if stud['m_edu'][i] not in range(0, 4):
        stud['m_edu'][i] = stud['f_edu'][i]
# Out:
# /Users/g.efremov/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/g.efremov/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
stud.f_edu.isna().unique()
# Out:
# array([False])

# %%
stud[['studytime_granular', 'study_time']].corr()
# Out:
#                     studytime_granular  study_time
# studytime_granular                 1.0        -1.0
# study_time                        -1.0         1.0

# %%
#100% corr - stud_time drop
stud.drop(['studytime_granular'], inplace = True, axis = 1)
stud.head()
# Out:
#   school sex  age address fam_size p_status  m_edu  f_edu    m_job    f_job  \
# 0     GP   F   18       U      NaN        A    4.0    4.0  at_home  teacher
# 1     GP   F   17       U      GT3      NaN    1.0    1.0  at_home    other
# 2     GP   F   15       U      LE3        T    1.0    1.0  at_home    other
# 3     GP   F   15       U      GT3        T    2.0    2.0   health      NaN
# 4     GP   F   16       U      GT3        T    3.0    3.0    other    other
#
#    reason guardian  travel_time  study_time  fail_res school_sup fam_sup paid  \
# 0  course   mother          2.0         2.0       0.0        yes      no   no
# 1  course   father          1.0         2.0       0.0         no     yes   no
# 2   other   mother          1.0         2.0       3.0        yes      no  NaN
# 3    home   mother          1.0         3.0       0.0         no     yes  yes
# 4    home   father          1.0         2.0       0.0         no     yes  yes
#
#   activities nursery higher internet romantic  fam_rel  free_time  go_out  \
# 0         no     yes    yes      NaN       no      4.0        3.0     4.0
# 1         no      no    yes      yes       no      5.0        3.0     3.0
# 2         no     yes    yes      yes      NaN      4.0        3.0     2.0
# 3        yes     yes    yes      yes      yes      3.0        2.0     2.0
# 4         no     yes    yes       no       no      4.0        3.0     2.0
#
#    health  absences  score
# 0     3.0       6.0   30.0
# 1     3.0       4.0   30.0
# 2     3.0      10.0   50.0
# 3     5.0       2.0   75.0
# 4     5.0       4.0   50.0

# %%
stud[stud.address == 'U'].travel_time.median()
# Out:
# 1.0

# %%
# пустые значения времени в пути заполняем по медиане адреса, пустые адреса - по указанному пути 
# если пусто и то и другое - по медиане принцыпа выбора школы
r_mean_time = stud[stud.address == 'R'].travel_time.median()
u_mean_time = stud[stud.address == 'U'].travel_time.median()
for i in stud[stud.travel_time.isna()].index:
    if stud.loc[i, 'address'] == 'R':
        stud.loc[i, 'travel_time'] = r_mean_time
    elif stud.loc[i, 'address'] == 'U':
        stud.loc[i, 'travel_time'] = u_mean_time
        
for i in stud[stud.address.isna()].index:
    if stud.loc[i, 'travel_time'] >= r_mean_time:
        stud.loc[i, 'address'] = 'R'
    elif stud.loc[i, 'travel_time'] <= u_mean_time:
        stud.loc[i, 'address'] = 'U'
        
for i in stud[(stud.address.isna() & stud.travel_time.isna())].index:
    temp_reason = stud.loc[i, 'reason']
    stud.loc[i, 'address'] = stud[stud.reason == temp_reason].address.mode()[0]
    stud.loc[i, 'travel_time'] = stud[stud.reason == temp_reason].travel_time.median()

# %%
study_time_mean = round(stud.study_time.mean())
stud.study_time = stud.study_time.apply(lambda x: study_time_mean if pd.isna(x) else x)

# %%
fail_res_mean = round(stud.fail_res.mean())
stud.fail_res = stud.fail_res.apply(lambda x: fail_res_mean if pd.isna(x) else x)

# %%
absences_mean = round(stud.absences.mean())
stud.absences = stud.absences.apply(lambda x: absences_mean if pd.isna(x) else x)

# %%
score_mean = round(stud.score.mean())
stud.score = stud.score.apply(lambda x: score_mean if pd.isna(x) else x)

# %%
go_out_mean = round(stud.go_out.mean())
stud.go_out = stud.go_out.apply(lambda x: go_out_mean if pd.isna(x) else x)

# %%
stud.head()
# Out:
#   school sex  age address fam_size p_status  m_edu  f_edu    m_job    f_job  \
# 0     GP   F   18       U      NaN        A    4.0    4.0  at_home  teacher
# 1     GP   F   17       U      GT3      NaN    1.0    1.0  at_home    other
# 2     GP   F   15       U      LE3        T    1.0    1.0  at_home    other
# 3     GP   F   15       U      GT3        T    2.0    2.0   health      NaN
# 4     GP   F   16       U      GT3        T    3.0    3.0    other    other
#
#    reason guardian  travel_time  study_time  fail_res school_sup fam_sup paid  \
# 0  course   mother          2.0         2.0       0.0        yes      no   no
# 1  course   father          1.0         2.0       0.0         no     yes   no
# 2   other   mother          1.0         2.0       3.0        yes      no  NaN
# 3    home   mother          1.0         3.0       0.0         no     yes  yes
# 4    home   father          1.0         2.0       0.0         no     yes  yes
#
#   activities nursery higher internet romantic  fam_rel  free_time  go_out  \
# 0         no     yes    yes      NaN       no      4.0        3.0     4.0
# 1         no      no    yes      yes       no      5.0        3.0     3.0
# 2         no     yes    yes      yes      NaN      4.0        3.0     2.0
# 3        yes     yes    yes      yes      yes      3.0        2.0     2.0
# 4         no     yes    yes       no       no      4.0        3.0     2.0
#
#    health  absences  score
# 0     3.0       6.0   30.0
# 1     3.0       4.0   30.0
# 2     3.0      10.0   50.0
# 3     5.0       2.0   75.0
# 4     5.0       4.0   50.0

# %%
print(f'There are {stud.isnull().any().sum()} columns in dataset with missing values.')
# Out:
# There are 16 columns in dataset with missing values.

# %%
stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       395 non-null    object
#  1   sex          395 non-null    object
#  2   age          395 non-null    int64
#  3   address      395 non-null    object
#  4   fam_size     368 non-null    object
#  5   p_status     350 non-null    object
#  6   m_edu        395 non-null    float64
#  7   f_edu        395 non-null    float64
#  8   m_job        376 non-null    object
#  9   f_job        359 non-null    object
#  10  reason       378 non-null    object
#  11  guardian     364 non-null    object
#  12  travel_time  395 non-null    float64
#  13  study_time   395 non-null    float64
#  14  fail_res     395 non-null    float64
#  15  school_sup   386 non-null    object
#  16  fam_sup      356 non-null    object
#  17  paid         355 non-null    object
#  18  activities   381 non-null    object
#  19  nursery      395 non-null    object
#  20  higher       375 non-null    object
#  21  internet     361 non-null    object
#  22  romantic     364 non-null    object
#  23  fam_rel      368 non-null    float64
#  24  free_time    384 non-null    float64
#  25  go_out       395 non-null    float64
#  26  health       380 non-null    float64
#  27  absences     395 non-null    float64
#  28  score        395 non-null    float64
# dtypes: float64(11), int64(1), object(17)
# memory usage: 89.6+ KB

# %%
stud.corr()
# Out:
#                   age     m_edu     f_edu  travel_time  study_time  fail_res  \
# age          1.000000 -0.105599 -0.157983     0.084853   -0.015355  0.228081
# m_edu       -0.105599  1.000000  0.801292    -0.144454    0.017884 -0.216882
# f_edu       -0.157983  0.801292  1.000000    -0.166053   -0.011408 -0.252957
# travel_time  0.084853 -0.144454 -0.166053     1.000000   -0.099989  0.068852
# study_time  -0.015355  0.017884 -0.011408    -0.099989    1.000000 -0.166598
# fail_res     0.228081 -0.216882 -0.252957     0.068852   -0.166598  1.000000
# fam_rel      0.068899 -0.007363 -0.037596    -0.004855    0.045308 -0.030492
# free_time    0.029023  0.016796 -0.012235    -0.021516   -0.120215  0.094530
# go_out       0.134069  0.075678  0.062781     0.052532   -0.051090  0.113649
# health      -0.065946  0.017596  0.005847    -0.031102   -0.079415  0.078668
# absences     0.092241  0.006837  0.036913    -0.043010   -0.026201  0.056247
# score       -0.153481  0.163117  0.135556    -0.076461    0.114074 -0.328451
#
#               fam_rel  free_time    go_out    health  absences     score
# age          0.068899   0.029023  0.134069 -0.065946  0.092241 -0.153481
# m_edu       -0.007363   0.016796  0.075678  0.017596  0.006837  0.163117
# f_edu       -0.037596  -0.012235  0.062781  0.005847  0.036913  0.135556
# travel_time -0.004855  -0.021516  0.052532 -0.031102 -0.043010 -0.076461
# study_time   0.045308  -0.120215 -0.051090 -0.079415 -0.026201  0.114074
# fail_res    -0.030492   0.094530  0.113649  0.078668  0.056247 -0.328451
# fam_rel      1.000000   0.175743  0.081510  0.077474 -0.081656  0.056801
# free_time    0.175743   1.000000  0.293111  0.061575  0.009169  0.018869
# go_out       0.081510   0.293111  1.000000 -0.015029 -0.047745 -0.127048
# health       0.077474   0.061575 -0.015029  1.000000 -0.015853 -0.070237
# absences    -0.081656   0.009169 -0.047745 -0.015853  1.000000  0.063900
# score        0.056801   0.018869 -0.127048 -0.070237  0.063900  1.000000

# %%
stud
# Out:
#     school sex  age address fam_size p_status  m_edu  f_edu     m_job  \
# 0       GP   F   18       U      NaN        A    4.0    4.0   at_home
# 1       GP   F   17       U      GT3      NaN    1.0    1.0   at_home
# 2       GP   F   15       U      LE3        T    1.0    1.0   at_home
# 3       GP   F   15       U      GT3        T    2.0    2.0    health
# 4       GP   F   16       U      GT3        T    3.0    3.0     other
# 5       GP   M   16       U      LE3        T    3.0    3.0  services
# 6       GP   M   16       U      LE3        T    2.0    2.0     other
# 7       GP   F   17       U      GT3        A    4.0    4.0     other
# 8       GP   M   15       U      LE3        A    3.0    2.0  services
# 9       GP   M   15       U      NaN      NaN    3.0    3.0     other
# 10      GP   F   15       U      GT3        T    4.0    4.0   teacher
# 11      GP   F   15       U      GT3      NaN    2.0    2.0  services
# 12      GP   M   15       U      LE3        T    4.0    4.0    health
# 13      GP   M   15       U      GT3        T    3.0    3.0   teacher
# 14      GP   M   15       U      GT3        A    2.0    2.0     other
# 15      GP   F   16       U      GT3      NaN    4.0    4.0    health
# 16      GP   F   16       U      GT3        T    4.0    4.0  services
# 17      GP   F   16       U      GT3        T    3.0    3.0     other
# 18      GP   M   17       U      GT3        T    3.0    2.0  services
# 19      GP   M   16       U      LE3        T    3.0    3.0    health
# 20      GP   M   15       U      GT3        T    3.0    3.0   teacher
# 21      GP   M   15       U      GT3        T    4.0    4.0    health
# 22      GP   M   16       U      LE3        T    2.0    2.0   teacher
# 23      GP   M   16       U      LE3        T    2.0    2.0     other
# 24      GP   F   15       R      GT3        T    2.0    2.0  services
# 25      GP   F   16       U      GT3      NaN    2.0    2.0  services
# 26      GP   M   15       U      GT3        T    2.0    2.0     other
# 27      GP   M   15       U      GT3        T    2.0    2.0    health
# 28      GP   M   16       U      LE3      NaN    3.0    3.0  services
# 29      GP   M   16       U      GT3        T    4.0    4.0       NaN
# 30      GP   M   15       U      GT3        T    4.0    4.0    health
# 31      GP   M   15       U      GT3        T    4.0    4.0  services
# 32      GP   M   15       R      NaN        T    3.0    3.0   teacher
# 33      GP   M   15       U      LE3        T    3.0    3.0     other
# 34      GP   M   16       U      GT3        T    3.0    2.0     other
# 35      GP   F   15       U      GT3        T    2.0    3.0     other
# 36      GP   M   15       U      NaN        T    3.0    3.0   teacher
# 37      GP   M   16       R      GT3        A    4.0    4.0     other
# 38      GP   F   15       R      GT3        T    3.0    3.0  services
# 39      GP   F   15       R      GT3        T    2.0    2.0   at_home
# 40      GP   F   16       U      LE3        T    2.0    2.0     other
# 41      GP   M   15       U      LE3        T    4.0    4.0   teacher
# 42      GP   M   15       U      GT3        T    4.0    4.0  services
# 43      GP   M   15       U      GT3        T    2.0    2.0  services
# 44      GP   F   16       U      LE3        T    2.0    2.0     other
# 45      GP   F   15       U      LE3        A    3.0    3.0     other
# 46      GP   F   16       U      LE3        A    3.0    3.0     other
# 47      GP   M   16       U      GT3        T    3.0    3.0    health
# 48      GP   M   15       U      GT3        T    2.0    2.0   teacher
# 49      GP   F   15       U      GT3        T    4.0    4.0  services
# 50      GP   F   16       U      LE3        T    2.0    2.0  services
# 51      GP   F   15       U      LE3        T    2.0    2.0    health
# 52      GP   M   15       R      LE3        A    2.0    2.0    health
# 53      GP   F   15       U      GT3        T    4.0    4.0  services
# 54      GP   F   15       U      LE3      NaN    3.0    3.0       NaN
# 55      GP   F   16       U      GT3        A    2.0    1.0     other
# 56      GP   F   15       U      GT3        A    3.0    3.0  services
# 57      GP   M   15       U      GT3        T    4.0    4.0   teacher
# 58      GP   M   15       U      LE3        T    1.0    1.0     other
# 59      GP   F   16       U      GT3        T    2.0    2.0       NaN
# 60      GP   F   16       R      GT3        T    4.0    4.0    health
# 61      GP   F   16       U      GT3        T    1.0    1.0  services
# 62      GP   F   16       U      LE3        T    1.0    2.0     other
# 63      GP   F   16       U      GT3      NaN    3.0    3.0   teacher
# 64      GP   F   15       U      LE3        T    3.0    3.0  services
# 65      GP   F   16       U      LE3        T    3.0    3.0   teacher
# 66      GP   M   15       U      GT3        A    4.0    4.0     other
# 67      GP   F   16       U      GT3      NaN    3.0    3.0  services
# 68      GP   F   15       R      LE3        T    2.0    2.0    health
# 69      GP   F   15       R      LE3        T    3.0    1.0     other
# 70      GP   M   16       U      GT3        T    3.0    1.0     other
# 71      GP   M   15       U      GT3        T    2.0    2.0     other
# 72      GP   F   15       R      GT3        T    1.0    1.0     other
# 73      GP   M   16       U      GT3        T    3.0    1.0     other
# 74      GP   F   16       U      GT3        T    3.0    3.0     other
# 75      GP   M   15       U      GT3        T    3.0    3.0   teacher
# 76      GP   M   15       U      NaN        T    0.0    0.0   teacher
# 77      GP   F   16       U      GT3        T    2.0    2.0     other
# 78      GP   M   17       U      NaN        T    2.0    1.0     other
# 79      GP   F   16       U      NaN        T    3.0    3.0   at_home
# 80      GP   M   15       U      GT3        T    2.0    3.0     other
# 81      GP   M   15       U      GT3      NaN    2.0    3.0     other
# 82      GP   F   15       U      LE3        T    3.0    2.0  services
# 83      GP   M   15       U      LE3        T    2.0    2.0  services
# 84      GP   F   15       U      GT3        T    1.0    1.0     other
# 85      GP   F   15       U      GT3        T    4.0    4.0  services
# 86      GP   F   16       U      LE3        T    2.0    2.0   at_home
# 87      GP   F   15       U      GT3        T    2.0    2.0     other
# 88      GP   M   16       U      GT3        T    2.0    2.0       NaN
# 89      GP   M   16       U      LE3        A    4.0    4.0   teacher
# 90      GP   F   16       U      GT3        T    3.0    3.0     other
# 91      GP   F   15       U      GT3        T    3.0    3.0  services
# 92      GP   F   16       U      LE3        T    1.0    1.0     other
# 93      GP   F   16       U      GT3        T    2.0    2.0   teacher
# 94      GP   M   15       U      LE3        T    2.0    2.0  services
# 95      GP   F   15       R      GT3        T    1.0    1.0   at_home
# 96      GP   M   16       R      GT3      NaN    3.0    3.0  services
# 97      GP   F   16       U      GT3        T    2.0    1.0     other
# 98      GP   F   16       U      GT3        T    4.0    4.0     other
# 99      GP   F   16       U      GT3        T    3.0    3.0     other
# 100     GP   M   16       U      GT3        T    4.0    4.0  services
# 101     GP   M   16       U      GT3        T    4.0    4.0  services
# 102     GP   M   15       U      GT3        T    4.0    4.0  services
# 103     GP   F   15       U      GT3        T    3.0    2.0  services
# 104     GP   M   15       U      GT3        A    3.0    3.0       NaN
# 105     GP   F   15       U      GT3        A    3.0    3.0     other
# 106     GP   F   15       U      GT3        T    2.0    2.0     other
# 107     GP   M   16       U      GT3        T    3.0    3.0  services
# 108     GP   M   15       R      GT3      NaN    4.0    4.0     other
# 109     GP   F   16       U      LE3        T    4.0    4.0    health
# 110     GP   M   15       U      LE3        A    4.0    4.0   teacher
# 111     GP   F   16       R      GT3        T    3.0    3.0  services
# 112     GP   F   16       U      GT3      NaN    2.0    2.0   at_home
# 113     GP   M   15       U      LE3        T    2.0    2.0   teacher
# 114     GP   M   15       R      NaN        T    2.0    1.0    health
# 115     GP   M   16       U      GT3        T    4.0    4.0   teacher
# 116     GP   M   15       U      GT3        T    4.0    4.0     other
# 117     GP   M   16       U      GT3        T    3.0    3.0     other
# 118     GP   M   17       R      GT3        T    1.0    3.0     other
# 119     GP   M   15       U      GT3        T    3.0    3.0     other
# 120     GP   F   15       U      GT3        T    1.0    2.0   at_home
# 121     GP   M   15       U      GT3        T    2.0    2.0  services
# 122     GP   F   16       U      LE3        T    2.0    2.0     other
# 123     GP   M   16       U      GT3        T    4.0    4.0    health
# 124     GP   F   16       U      GT3        T    2.0    2.0     other
# 125     GP   M   15       U      GT3        T    3.0    3.0  services
# 126     GP   F   15       U      LE3        A    3.0    3.0     other
# 127     GP   F   19       U      GT3        T    0.0    1.0   at_home
# 128     GP   M   18       R      NaN        T    2.0    2.0       NaN
# 129     GP   M   16       R      NaN        T    4.0    4.0   teacher
# 130     GP   F   15       R      GT3        T    3.0    3.0  services
# 131     GP   F   15       U      GT3      NaN    1.0    1.0   at_home
# 132     GP   F   17       U      LE3        T    2.0    2.0     other
# 133     GP   F   16       U      GT3        A    3.0    3.0  services
# 134     GP   M   15       R      GT3        T    3.0    3.0   at_home
# 135     GP   F   15       U      GT3        T    4.0    4.0  services
# 136     GP   M   17       R      GT3        T    3.0    3.0   at_home
# 137     GP   F   16       U      GT3        A    3.0    3.0     other
# 138     GP   M   16       U      LE3        T    1.0    1.0  services
# 139     GP   F   15       U      GT3      NaN    4.0    4.0   teacher
# 140     GP   M   15       U      GT3        T    3.0    3.0   teacher
# 141     GP   M   16       U      LE3        T    2.0    2.0  services
# 142     GP   F   15       U      GT3        T    4.0    4.0   teacher
# 143     GP   F   16       U      LE3        T    1.0    1.0   at_home
# 144     GP   M   17       U      GT3        T    2.0    1.0     other
# 145     GP   F   15       U      GT3        T    1.0    1.0       NaN
# 146     GP   F   15       U      GT3        T    3.0    2.0    health
# 147     GP   F   15       U      GT3      NaN    1.0    2.0   at_home
# 148     GP   M   16       U      GT3        T    4.0    4.0   teacher
# 149     GP   M   15       U      LE3      NaN    2.0    1.0  services
# 150     GP   M   18       U      LE3        T    1.0    1.0     other
# 151     GP   M   16       U      LE3        T    2.0    1.0   at_home
# 152     GP   F   15       R      GT3        T    3.0    3.0  services
# 153     GP   M   19       U      GT3      NaN    3.0    2.0  services
# 154     GP   F   17       U      GT3        T    4.0    4.0     other
# 155     GP   M   15       R      GT3        T    2.0    3.0   at_home
# 156     GP   M   17       R      LE3        T    1.0    2.0       NaN
# 157     GP   F   18       R      GT3        T    1.0    1.0   at_home
# 158     GP   M   16       R      GT3      NaN    2.0    2.0   at_home
# 159     GP   M   16       U      GT3        T    3.0    3.0     other
# 160     GP   M   17       R      LE3        T    2.0    1.0   at_home
# 161     GP   M   15       R      GT3        T    3.0    3.0     other
# 162     GP   M   16       U      LE3        T    1.0    2.0     other
# 163     GP   M   17       U      GT3        T    1.0    3.0   at_home
# 164     GP   M   17       R      LE3        T    1.0    1.0     other
# 165     GP   M   16       U      GT3        T    3.0    2.0  services
# 166     GP   M   16       U      GT3        T    2.0    2.0       NaN
# 167     GP   F   16       U      NaN        T    2.0    2.0    health
# 168     GP   F   16       U      GT3        T    2.0    2.0     other
# 169     GP   F   16       U      GT3        T    4.0    4.0    health
# 170     GP   M   16       U      GT3        T    3.0    3.0     other
# 171     GP   M   16       U      GT3        T    1.0    0.0     other
# 172     GP   M   17       U      NaN        T    4.0    4.0   teacher
# 173     GP   F   16       U      GT3        T    1.0    3.0   at_home
# 174     GP   F   16       U      LE3      NaN    3.0    3.0       NaN
# 175     GP   M   17       U      LE3        T    3.0    3.0   teacher
# 176     GP   F   16       U      GT3        T    2.0    2.0  services
# 177     GP   M   17       U      GT3        T    3.0    3.0       NaN
# 178     GP   M   16       R      GT3        T    2.0    2.0   teacher
# 179     GP   M   17       U      GT3        T    3.0    3.0     other
# 180     GP   M   16       U      GT3        T    4.0    4.0   teacher
# 181     GP   M   16       U      GT3        T    3.0    3.0  services
# 182     GP   F   17       U      GT3      NaN    2.0    2.0  services
# 183     GP   F   17       U      LE3      NaN    3.0    3.0     other
# 184     GP   F   16       U      GT3        T    3.0    2.0     other
# 185     GP   M   17       U      GT3        T    3.0    3.0  services
# 186     GP   M   16       U      GT3      NaN    1.0    2.0  services
# 187     GP   M   16       U      LE3        T    2.0    1.0     other
# 188     GP   F   17       U      GT3        A    3.0    3.0    health
# 189     GP   M   17       R      GT3        T    1.0    2.0   at_home
# 190     GP   F   16       U      GT3        T    2.0    3.0  services
# 191     GP   F   17       U      GT3        T    1.0    1.0   at_home
# 192     GP   M   17       U      GT3        T    1.0    2.0   at_home
# 193     GP   M   16       R      GT3      NaN    3.0    3.0  services
# 194     GP   M   16       U      GT3        T    2.0    3.0     other
# 195     GP   F   17       U      NaN        T    2.0    2.0  services
# 196     GP   M   17       U      GT3        T    4.0    4.0  services
# 197     GP   M   16       R      LE3      NaN    3.0    3.0   teacher
# 198     GP   F   17       U      GT3      NaN    4.0    4.0  services
# 199     GP   F   16       U      LE3        T    4.0    4.0   teacher
# 200     GP   F   16       U      GT3        T    3.0    3.0    health
# 201     GP   F   16       U      GT3        T    2.0    3.0     other
# 202     GP   F   17       U      NaN        T    1.0    1.0     other
# 203     GP   F   17       R      GT3        T    2.0    2.0     other
# 204     GP   F   16       R      GT3        T    2.0    2.0  services
# 205     GP   F   17       U      GT3        T    3.0    3.0   at_home
# 206     GP   F   16       U      GT3        A    3.0    1.0  services
# 207     GP   F   16       U      GT3        T    3.0    3.0   teacher
# 208     GP   F   16       U      GT3        T    1.0    1.0   at_home
# 209     GP   F   17       R      GT3        T    3.0    3.0   teacher
# 210     GP   F   19       U      GT3      NaN    3.0    3.0     other
# 211     GP   M   17       U      LE3        T    4.0    4.0  services
# 212     GP   F   16       U      GT3        A    2.0    2.0     other
# 213     GP   M   18       U      GT3        T    2.0    2.0  services
# 214     GP   F   17       R      LE3        T    4.0    4.0  services
# 215     GP   F   17       U      LE3        T    3.0    2.0     other
# 216     GP   F   17       U      GT3        T    3.0    3.0     other
# 217     GP   M   18       U      LE3        T    3.0    3.0  services
# 218     GP   F   17       U      GT3        T    2.0    3.0   at_home
# 219     GP   F   17       U      GT3        T    2.0    2.0       NaN
# 220     GP   F   17       R      GT3        T    2.0    1.0   at_home
# 221     GP   F   17       U      NaN        T    1.0    1.0   at_home
# 222     GP   F   16       U      GT3        T    2.0    3.0  services
# 223     GP   M   18       U      GT3        T    2.0    2.0     other
# 224     GP   F   16       U      GT3        T    4.0    4.0       NaN
# 225     GP   F   18       R      GT3        T    3.0    1.0     other
# 226     GP   F   17       U      GT3        T    3.0    2.0     other
# 227     GP   M   17       U      LE3      NaN    2.0    3.0  services
# 228     GP   M   18       U      NaN        T    2.0    1.0   at_home
# 229     GP   F   17       U      GT3        A    2.0    1.0     other
# 230     GP   F   17       U      LE3        T    3.0    3.0    health
# 231     GP   M   17       R      GT3        T    2.0    2.0     other
# 232     GP   M   17       U      GT3        T    4.0    4.0   teacher
# 233     GP   M   16       U      GT3        T    4.0    4.0    health
# 234     GP   M   16       U      LE3      NaN    1.0    1.0     other
# 235     GP   M   16       U      NaN        T    3.0    2.0   at_home
# 236     GP   M   17       U      LE3        T    2.0    2.0     other
# 237     GP   F   16       U      NaN        T    2.0    1.0     other
# 238     GP   F   17       R      GT3        T    2.0    1.0   at_home
# 239     GP   M   18       U      GT3      NaN    2.0    2.0     other
# 240     GP   M   17       U      LE3        T    3.0    3.0    health
# 241     GP   M   17       U      LE3        A    4.0    4.0   teacher
# 242     GP   M   16       U      LE3        T    3.0    3.0   teacher
# 243     GP   M   16       U      GT3        T    4.0    4.0  services
# 244     GP   F   18       U      GT3        T    2.0    1.0     other
# 245     GP   M   16       U      GT3      NaN    2.0    1.0     other
# 246     GP   M   17       U      GT3        T    2.0    3.0     other
# 247     GP   M   22       U      GT3        T    3.0    1.0  services
# 248     GP   M   18       R      LE3        T    3.0    3.0     other
# 249     GP   M   16       U      GT3        T    0.0    2.0     other
# 250     GP   M   18       U      GT3        T    3.0    2.0  services
# 251     GP   M   16       U      GT3        T    3.0    3.0   at_home
# 252     GP   M   18       U      NaN      NaN    2.0    1.0  services
# 253     GP   M   16       R      NaN        T    2.0    1.0     other
# 254     GP   M   17       U      NaN        T    2.0    1.0     other
# 255     GP   M   17       U      LE3        T    1.0    1.0    health
# 256     GP   F   17       U      LE3        T    2.0    2.0   teacher
# 257     GP   M   19       U      LE3        A    3.0    3.0  services
# 258     GP   M   18       U      GT3        T    2.0    1.0     other
# 259     GP   F   17       U      LE3        T    2.0    2.0  services
# 260     GP   F   18       U      GT3      NaN    3.0    3.0       NaN
# 261     GP   M   18       U      GT3        T    3.0    3.0   teacher
# 262     GP   M   18       R      GT3        T    3.0    2.0     other
# 263     GP   F   17       U      GT3        T    3.0    3.0     other
# 264     GP   F   18       U      GT3        T    2.0    2.0   at_home
# 265     GP   M   18       R      LE3      NaN    3.0    3.0       NaN
# 266     GP   M   17       U      GT3      NaN    3.0    1.0  services
# 267     GP   F   18       R      GT3        T    4.0    4.0   teacher
# 268     GP   M   18       U      NaN      NaN    2.0    2.0       NaN
# 269     GP   F   18       R      GT3        T    2.0    1.0     other
# 270     GP   F   19       U      GT3        T    3.0    3.0     other
# 271     GP   F   18       U      GT3      NaN    2.0    3.0     other
# 272     GP   F   18       U      LE3        T    1.0    1.0     other
# 273     GP   M   17       R      GT3        T    1.0    2.0   at_home
# 274     GP   F   17       U      GT3        T    2.0    2.0   at_home
# 275     GP   F   17       U      LE3        T    2.0    2.0  services
# 276     GP   F   18       R      GT3        A    3.0    2.0     other
# 277     GP   M   18       U      GT3        T    4.0    4.0       NaN
# 278     GP   F   18       U      GT3        T    4.0    4.0    health
# 279     GP   M   18       U      LE3        T    3.0    3.0   teacher
# 280     GP   M   17       U      NaN        A    4.0    4.0  services
# 281     GP   M   17       U      LE3        A    3.0    3.0   teacher
# 282     GP   F   18       R      LE3      NaN    1.0    1.0   at_home
# 283     GP   F   18       U      GT3        T    1.0    1.0     other
# 284     GP   F   17       U      GT3        T    2.0    2.0     other
# 285     GP   M   17       U      GT3        T    1.0    1.0     other
# 286     GP   F   18       U      GT3        T    2.0    2.0   at_home
# 287     GP   F   17       U      GT3        T    1.0    1.0  services
# 288     GP   M   18       U      GT3        T    2.0    1.0  services
# 289     GP   M   18       U      LE3        A    4.0    4.0   teacher
# 290     GP   M   18       U      GT3        T    4.0    4.0   teacher
# 291     GP   F   17       U      GT3        T    3.0    3.0       NaN
# 292     GP   F   18       U      LE3        T    2.0    1.0  services
# 293     GP   F   17       R      LE3        T    3.0    1.0  services
# 294     GP   M   18       R      LE3        T    3.0    2.0  services
# 295     GP   M   17       U      GT3        T    3.0    3.0    health
# 296     GP   F   19       U      GT3        T    4.0    4.0    health
# 297     GP   F   18       U      LE3        T    3.0    3.0     other
# 298     GP   F   18       U      GT3      NaN    3.0    3.0     other
# 299     GP   M   18       U      LE3        T    4.0    4.0   teacher
# 300     GP   F   18       U      LE3        A    4.0    4.0    health
# 301     GP   M   17       U      LE3        T    4.0    4.0     other
# 302     GP   F   17       U      GT3        T    2.0    2.0     other
# 303     GP   F   17       U      GT3        T    3.0    2.0    health
# 304     GP   M   19       U      GT3        T    3.0    3.0     other
# 305     GP   F   18       U      GT3        T    2.0    2.0  services
# 306     GP   M   20       U      GT3        A    3.0    2.0  services
# 307     GP   M   19       U      GT3      NaN    4.0    4.0   teacher
# 308     GP   M   19       R      GT3        T    3.0    3.0     other
# 309     GP   F   19       U      LE3        T    1.0    1.0   at_home
# 310     GP   F   19       U      LE3        T    1.0    1.0  services
# 311     GP   F   19       U      GT3        T    2.0    1.0   at_home
# 312     GP   M   19       U      GT3        T    1.0    2.0     other
# 313     GP   F   19       U      NaN      NaN    3.0    2.0  services
# 314     GP   F   19       U      GT3        T    1.0    1.0   at_home
# 315     GP   F   19       R      GT3        T    2.0    3.0     other
# 316     GP   F   18       U      GT3        T    2.0    1.0  services
# 317     GP   F   18       U      GT3        T    3.0    3.0     other
# 318     GP   F   17       R      GT3        T    3.0    3.0   at_home
# 319     GP   F   18       U      GT3        T    4.0    4.0   teacher
# 320     GP   F   17       U      GT3        A    3.0    3.0  services
# 321     GP   F   17       U      GT3        T    2.0    2.0     other
# 322     GP   F   17       R      LE3        T    2.0    2.0  services
# 323     GP   F   17       U      GT3        T    3.0    1.0  services
# 324     GP   F   17       U      LE3        T    0.0    2.0   at_home
# 325     GP   M   18       U      GT3        T    4.0    4.0     other
# 326     GP   M   17       U      GT3        T    3.0    3.0     other
# 327     GP   M   17       R      GT3        T    2.0    2.0  services
# 328     GP   F   17       U      GT3        T    4.0    4.0   teacher
# 329     GP   F   17       U      GT3        T    4.0    4.0   teacher
# 330     GP   M   18       U      LE3        T    2.0    2.0     other
# 331     GP   F   17       R      GT3        T    2.0    2.0   at_home
# 332     GP   F   18       U      GT3        T    3.0    3.0  services
# 333     GP   F   18       U      LE3      NaN    2.0    2.0     other
# 334     GP   F   18       R      GT3        T    2.0    2.0   at_home
# 335     GP   F   17       U      GT3        T    3.0    3.0  services
# 336     GP   F   19       R      GT3        A    3.0    1.0  services
# 337     GP   F   17       U      GT3        T    3.0    2.0       NaN
# 338     GP   F   18       U      LE3        T    3.0    3.0  services
# 339     GP   F   17       R      GT3        A    3.0    2.0     other
# 340     GP   F   19       U      GT3        T    2.0    1.0  services
# 341     GP   M   18       U      GT3        T    4.0    4.0   teacher
# 342     GP   M   18       U      LE3      NaN    3.0    3.0  services
# 343     GP   F   17       U      GT3        A    2.0    2.0   at_home
# 344     GP   F   18       U      NaN        T    2.0    3.0   at_home
# 345     GP   F   18       U      GT3        T    3.0    2.0     other
# 346     GP   M   18       R      GT3        T    3.0    3.0   teacher
# 347     GP   M   18       U      GT3        T    3.0    3.0   teacher
# 348     GP   F   17       U      GT3        T    3.0    3.0    health
# 349     MS   M   18       R      GT3        T    3.0    3.0     other
# 350     MS   M   19       R      GT3        T    1.0    1.0     other
# 351     MS   M   17       U      GT3        T    3.0    3.0    health
# 352     MS   M   18       U      LE3        T    1.0    3.0   at_home
# 353     MS   M   19       R      GT3        T    1.0    1.0     other
# 354     MS   M   17       R      GT3        T    3.0    3.0  services
# 355     MS   F   18       U      GT3        T    3.0    3.0  services
# 356     MS   F   17       R      GT3        T    4.0    4.0   teacher
# 357     MS   F   17       U      LE3      NaN    3.0    2.0  services
# 358     MS   M   18       U      LE3        T    1.0    1.0     other
# 359     MS   F   18       R      LE3        T    1.0    1.0   at_home
# 360     MS   F   18       R      NaN        A    1.0    1.0   at_home
# 361     MS   M   18       R      LE3        T    1.0    1.0   at_home
# 362     MS   F   18       U      GT3        T    3.0    3.0  services
# 363     MS   F   17       U      LE3        T    4.0    4.0   at_home
# 364     MS   F   17       R      GT3      NaN    1.0    2.0     other
# 365     MS   M   18       R      GT3        T    1.0    3.0   at_home
# 366     MS   M   18       U      LE3        T    4.0    4.0   teacher
# 367     MS   F   17       R      NaN        T    1.0    1.0     other
# 368     MS   F   18       U      GT3        T    2.0    3.0   at_home
# 369     MS   F   18       R      GT3        T    4.0    4.0     other
# 370     MS   F   19       U      LE3        T    3.0    2.0  services
# 371     MS   M   18       R      LE3        T    1.0    2.0   at_home
# 372     MS   F   17       U      GT3        T    2.0    2.0     other
# 373     MS   F   17       R      GT3        T    1.0    2.0     other
# 374     MS   F   18       R      LE3        T    4.0    4.0     other
# 375     MS   F   18       R      GT3        T    1.0    1.0     other
# 376     MS   F   20       R      GT3        T    2.0    2.0    health
# 377     MS   F   18       R      LE3        T    4.0    4.0   teacher
# 378     MS   F   18       U      GT3        T    3.0    3.0     other
# 379     MS   F   17       R      GT3        T    3.0    1.0   at_home
# 380     MS   M   18       U      GT3        T    4.0    4.0   teacher
# 381     MS   M   18       R      GT3        T    2.0    1.0     other
# 382     MS   M   17       U      GT3        T    2.0    3.0     other
# 383     MS   M   19       R      GT3        T    1.0    1.0     other
# 384     MS   M   18       R      GT3        T    2.0    2.0     other
# 385     MS   F   18       R      GT3        T    2.0    2.0   at_home
# 386     MS   F   18       R      GT3        T    4.0    4.0   teacher
# 387     MS   F   19       R      GT3        T    2.0    3.0  services
# 388     MS   F   18       U      LE3        T    3.0    1.0   teacher
# 389     MS   F   18       U      GT3        T    1.0    1.0     other
# 390     MS   M   20       U      LE3        A    2.0    2.0  services
# 391     MS   M   17       U      LE3        T    3.0    1.0  services
# 392     MS   M   21       R      GT3        T    1.0    1.0     other
# 393     MS   M   18       R      LE3        T    3.0    2.0  services
# 394     MS   M   19       U      LE3        T    1.0    1.0     other
#
#         f_job      reason guardian  travel_time  study_time  fail_res  \
# 0     teacher      course   mother          2.0         2.0       0.0
# 1       other      course   father          1.0         2.0       0.0
# 2       other       other   mother          1.0         2.0       3.0
# 3         NaN        home   mother          1.0         3.0       0.0
# 4       other        home   father          1.0         2.0       0.0
# 5       other  reputation   mother          1.0         2.0       0.0
# 6       other        home   mother          1.0         2.0       0.0
# 7     teacher        home   mother          2.0         2.0       0.0
# 8       other        home   mother          1.0         2.0       0.0
# 9       other        home   mother          1.0         2.0       0.0
# 10     health  reputation   mother          1.0         2.0       0.0
# 11      other  reputation   father          3.0         3.0       0.0
# 12   services      course   father          1.0         1.0       0.0
# 13      other      course   mother          2.0         2.0       0.0
# 14      other        home    other          1.0         3.0       0.0
# 15      other        home   mother          1.0         1.0       0.0
# 16   services  reputation   mother          1.0         3.0       0.0
# 17        NaN  reputation   mother          3.0         2.0       0.0
# 18   services      course   mother          1.0         1.0       3.0
# 19      other        home   father          1.0         1.0       0.0
# 20      other  reputation   mother          1.0         2.0       0.0
# 21     health       other   father          1.0         1.0       0.0
# 22        NaN      course   mother          1.0         2.0       0.0
# 23      other  reputation   mother          2.0         2.0       0.0
# 24     health      course   mother          1.0         3.0       0.0
# 25   services        home   mother          1.0         1.0       2.0
# 26        NaN        home   mother          1.0         1.0       0.0
# 27   services       other   mother          1.0         1.0       0.0
# 28      other        home   mother          1.0         2.0       0.0
# 29    teacher        home   mother          1.0         2.0       0.0
# 30   services        home   mother          1.0         2.0       0.0
# 31        NaN  reputation   mother          2.0         2.0       0.0
# 32    at_home      course   mother          1.0         2.0       0.0
# 33      other         NaN   mother          1.0         2.0       0.0
# 34      other        home   mother          1.0         1.0       0.0
# 35      other       other   father          1.0         1.0       0.0
# 36   services        home   mother          1.0         3.0       0.0
# 37    teacher  reputation   mother          2.0         3.0       0.0
# 38     health      course      NaN          1.0         3.0       0.0
# 39      other  reputation   mother          1.0         1.0       0.0
# 40      other        home   mother          2.0         2.0       1.0
# 41      other        home      NaN          1.0         1.0       0.0
# 42    teacher      course   father          1.0         2.0       0.0
# 43   services      course   father          1.0         1.0       0.0
# 44        NaN      course   father          2.0         2.0       1.0
# 45      other      course   mother          1.0         2.0       0.0
# 46   services        home   mother          1.0         2.0       0.0
# 47        NaN  reputation   mother          1.0         4.0       0.0
# 48      other        home   mother          1.0         2.0       0.0
# 49    teacher       other      NaN          1.0         2.0       1.0
# 50   services      course   mother          3.0         2.0       0.0
# 51      other       other   mother          1.0         2.0       0.0
# 52        NaN       other   father          2.0         1.0       1.0
# 53   services      course      NaN          1.0         1.0       0.0
# 54      other       other   mother          1.0         1.0       0.0
# 55      other       other   mother          1.0         2.0       0.0
# 56   services  reputation   mother          1.0         2.0       0.0
# 57     health  reputation   mother          1.0         2.0       0.0
# 58    at_home        home   father          1.0         2.0       0.0
# 59        NaN      course   mother          1.0         2.0       0.0
# 60    teacher       other      NaN          1.0         2.0       0.0
# 61   services      course   father          4.0         1.0       0.0
# 62   services  reputation   father          1.0         2.0       0.0
# 63     health         NaN   mother          1.0         3.0       0.0
# 64   services  reputation   father          1.0         2.0       0.0
# 65   services      course   mother          3.0         2.0       0.0
# 66   services  reputation   mother          1.0         4.0       0.0
# 67      other      course   mother          1.0         4.0       0.0
# 68        NaN  reputation   mother          2.0         2.0       0.0
# 69      other  reputation   father          2.0         4.0       0.0
# 70      other  reputation   father          1.0         4.0       0.0
# 71      other      course   mother          1.0         4.0       0.0
# 72      other  reputation   mother          1.0         2.0       2.0
# 73      other         NaN   mother          1.0         1.0       0.0
# 74   services        home   mother          1.0         2.0       0.0
# 75      other        home   mother          1.0         2.0       0.0
# 76      other      course   mother          2.0         4.0       0.0
# 77      other         NaN   mother          1.0         4.0       0.0
# 78      other        home   mother          2.0         1.0       3.0
# 79      other      course   mother          1.0         2.0       0.0
# 80   services      course   father          1.0         1.0       0.0
# 81      other        home      NaN          1.0         3.0       0.0
# 82      other  reputation   mother          1.0         2.0       0.0
# 83   services        home   mother          2.0         2.0       0.0
# 84      other        home   father          1.0         2.0       0.0
# 85   services  reputation   father          2.0         2.0       2.0
# 86      other      course   mother          1.0         2.0       0.0
# 87      other  reputation   mother          1.0         3.0       0.0
# 88      other  reputation   father          2.0         2.0       1.0
# 89     health  reputation   mother          1.0         2.0       0.0
# 90      other        home      NaN          1.0         3.0       0.0
# 91      other  reputation   mother          1.0         2.0       0.0
# 92      other        home   father          1.0         2.0       0.0
# 93   services        home   mother          2.0         2.0       0.0
# 94     health  reputation   mother          1.0         4.0       0.0
# 95      other        home   mother          2.0         4.0       1.0
# 96      other  reputation   mother          2.0         1.0       0.0
# 97      other      course   mother          1.0         2.0       0.0
# 98      other  reputation      NaN          1.0         1.0       0.0
# 99    at_home      course   mother          1.0         3.0       0.0
# 100  services       other   mother          1.0         1.0       0.0
# 101   teacher       other   father          1.0         3.0       0.0
# 102     other      course   mother          1.0         1.0       0.0
# 103     other        home   mother          2.0         2.0       0.0
# 104     other      course   mother          1.0         2.0       0.0
# 105    health  reputation   father          1.0         4.0       0.0
# 106     other      course   mother          1.0         4.0       0.0
# 107       NaN        home   father          1.0         3.0       0.0
# 108     other        home   father          4.0         4.0       0.0
# 109    health       other   mother          1.0         3.0       0.0
# 110   teacher      course   mother          1.0         1.0       0.0
# 111     other  reputation   father          1.0         3.0       1.0
# 112     other         NaN   mother          1.0         2.0       1.0
# 113     other      course   mother          1.0         1.0       0.0
# 114  services  reputation   mother          1.0         2.0       0.0
# 115   teacher      course   father          1.0         2.0       0.0
# 116   teacher  reputation   father          2.0         2.0       0.0
# 117  services        home   father          2.0         1.0       0.0
# 118       NaN      course   father          3.0         2.0       1.0
# 119     other  reputation   father          1.0         1.0       0.0
# 120       NaN      course   mother          1.0         2.0       0.0
# 121  services        home   father          1.0         4.0       0.0
# 122    health      course   father          2.0         2.0       0.0
# 123     other      course   mother          1.0         1.0       0.0
# 124     other        home   mother          1.0         2.0       0.0
# 125  services        home   father          1.0         1.0       0.0
# 126     other        home   mother          1.0         2.0       0.0
# 127     other      course    other          1.0         2.0       3.0
# 128     other  reputation   mother          1.0         1.0       2.0
# 129   teacher      course   mother          1.0         2.0       0.0
# 130   teacher      course   father          2.0         3.0       2.0
# 131     other      course   mother          3.0         1.0       0.0
# 132     other      course   father          1.0         1.0       0.0
# 133     other      course   father          1.0         1.0       0.0
# 134   teacher      course   mother          2.0         2.0       0.0
# 135       NaN      course   mother          1.0         3.0       0.0
# 136     other      course   mother          3.0         2.0       0.0
# 137     other         NaN    other          1.0         1.0       2.0
# 138     other         NaN      NaN          1.0         2.0       1.0
# 139   teacher      course   mother          2.0         1.0       0.0
# 140  services         NaN   father          2.0         4.0       0.0
# 141  services  reputation   father          2.0         1.0       2.0
# 142  services      course   mother          1.0         3.0       0.0
# 143   at_home      course   mother          1.0         1.0       0.0
# 144     other        home      NaN          1.0         1.0       3.0
# 145  services      course   father          1.0         2.0       0.0
# 146  services        home   father          1.0         2.0       3.0
# 147     other      course   mother          1.0         2.0       0.0
# 148   teacher      course   mother          1.0         1.0       0.0
# 149     other      course   mother          4.0         1.0       3.0
# 150     other      course   mother          1.0         1.0       3.0
# 151       NaN      course   mother          1.0         1.0       1.0
# 152       NaN  reputation    other          2.0         3.0       2.0
# 153   at_home        home   mother          1.0         1.0       0.0
# 154   teacher      course   mother          1.0         1.0       0.0
# 155  services      course   mother          1.0         2.0       0.0
# 156     other  reputation   mother          1.0         1.0       0.0
# 157     other      course   mother          2.0         1.0       3.0
# 158     other      course   mother          3.0         1.0       0.0
# 159  services      course   father          1.0         2.0       1.0
# 160       NaN      course   mother          2.0         1.0       2.0
# 161       NaN      course   mother          2.0         2.0       2.0
# 162     other      course   mother          2.0         1.0       1.0
# 163  services      course   father          1.0         1.0       0.0
# 164  services      course      NaN          4.0         2.0       3.0
# 165  services      course   mother          2.0         1.0       1.0
# 166     other      course   father          1.0         2.0       0.0
# 167  services        home   father          1.0         2.0       0.0
# 168     other        home   mother          1.0         2.0       0.0
# 169       NaN  reputation   mother          1.0         2.0       0.0
# 170     other      course   father          3.0         1.0       0.0
# 171     other  reputation   mother          2.0         2.0       0.0
# 172     other  reputation   mother          1.0         2.0       0.0
# 173  services        home      NaN          1.0         2.0       3.0
# 174     other  reputation   mother          2.0         2.0       0.0
# 175     other      course   mother          2.0         2.0       0.0
# 176     other  reputation   mother          2.0         2.0       0.0
# 177     other  reputation   father          1.0         2.0       0.0
# 178  services       other   mother          1.0         1.0       0.0
# 179     other      course   mother          1.0         2.0       0.0
# 180     other        home   mother          1.0         2.0       0.0
# 181     other        home      NaN          1.0         2.0       0.0
# 182       NaN  reputation   father          1.0         2.0       0.0
# 183     other  reputation   mother          1.0         2.0       0.0
# 184     other  reputation   mother          1.0         2.0       0.0
# 185  services         NaN   mother          1.0         2.0       0.0
# 186  services         NaN   mother          1.0         1.0       0.0
# 187     other      course   mother          1.0         2.0       0.0
# 188     other  reputation   mother          1.0         2.0       0.0
# 189     other        home   mother          1.0         2.0       0.0
# 190  services      course   mother          1.0         2.0       0.0
# 191  services      course   mother          1.0         2.0       0.0
# 192  services       other    other          2.0         2.0       0.0
# 193  services  reputation   mother          1.0         1.0       0.0
# 194     other        home   father          2.0         1.0       0.0
# 195  services      course   father          1.0         2.0       0.0
# 196   teacher         NaN   mother          1.0         1.0       0.0
# 197     other        home   father          3.0         1.0       0.0
# 198   teacher        home   mother          2.0         1.0       1.0
# 199   teacher  reputation   mother          1.0         2.0       0.0
# 200     other        home   mother          1.0         2.0       0.0
# 201     other  reputation   mother          1.0         2.0       0.0
# 202     other      course   mother          1.0         2.0       0.0
# 203     other  reputation   mother          1.0         1.0       0.0
# 204  services  reputation   mother          2.0         4.0       0.0
# 205  services        home   mother          1.0         3.0       1.0
# 206     other      course   mother          1.0         2.0       3.0
# 207     other       other   mother          1.0         2.0       0.0
# 208     other        home   mother          2.0         1.0       0.0
# 209     other  reputation   mother          2.0         3.0       0.0
# 210     other  reputation    other          1.0         4.0       0.0
# 211     other        home   mother          1.0         2.0       0.0
# 212     other  reputation   mother          1.0         2.0       0.0
# 213     other        home   mother          1.0         2.0       1.0
# 214     other       other   mother          1.0         1.0       0.0
# 215     other  reputation   mother          2.0         2.0       0.0
# 216       NaN  reputation   mother          1.0         2.0       2.0
# 217    health        home   father          1.0         2.0       1.0
# 218     other        home   father          2.0         1.0       0.0
# 219   at_home      course   mother          1.0         3.0       0.0
# 220  services  reputation   mother          2.0         2.0       0.0
# 221     other  reputation   mother          1.0         3.0       1.0
# 222   teacher       other   mother          1.0         2.0       0.0
# 223     other        home      NaN          2.0         2.0       0.0
# 224  services        home   mother          1.0         3.0       0.0
# 225     other  reputation   mother          1.0         2.0       1.0
# 226     other      course   mother          1.0         2.0       0.0
# 227  services  reputation   father          1.0         2.0       0.0
# 228     other      course   mother          4.0         2.0       0.0
# 229       NaN      course   mother          2.0         3.0       0.0
# 230     other  reputation   father          1.0         2.0       0.0
# 231     other      course   father          2.0         2.0       0.0
# 232   teacher  reputation   mother          1.0         2.0       0.0
# 233     other  reputation   father          1.0         2.0       0.0
# 234     other        home   mother          1.0         2.0       0.0
# 235     other  reputation      NaN          2.0         3.0       0.0
# 236     other        home   father          1.0         2.0       0.0
# 237     other        home   mother          1.0         1.0       0.0
# 238  services      course   mother          3.0         2.0       0.0
# 239  services  reputation   father          1.0         2.0       1.0
# 240     other      course      NaN          2.0         2.0       0.0
# 241     other      course   mother          1.0         2.0       0.0
# 242     other      course   mother          1.0         1.0       0.0
# 243  services      course   mother          1.0         1.0       0.0
# 244     other      course    other          2.0         3.0       0.0
# 245     other      course   mother          3.0         1.0       0.0
# 246     other      course   father          2.0         1.0       0.0
# 247  services       other   mother          1.0         1.0       3.0
# 248  services      course   mother          1.0         2.0       1.0
# 249     other       other   mother          1.0         1.0       0.0
# 250       NaN      course   mother          2.0         1.0       1.0
# 251     other  reputation    other          3.0         2.0       0.0
# 252  services       other   mother          1.0         1.0       1.0
# 253     other      course   mother          2.0         1.0       0.0
# 254     other      course   mother          1.0         1.0       0.0
# 255     other      course   mother          2.0         1.0       1.0
# 256  services  reputation   mother          1.0         4.0       0.0
# 257   at_home  reputation   mother          1.0         2.0       0.0
# 258     other        home      NaN          1.0         2.0       0.0
# 259  services      course   father          1.0         4.0       0.0
# ...
